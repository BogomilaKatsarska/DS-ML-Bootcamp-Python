# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

x = np.arange(0, 100)
y = x * 2
z = x ** 2

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')
